# %%
# 1. What is Pivot Table In Excel

# %%
# 2. Explain about V look up and H look up. And on which cases we use False at the end of the look up formula.

# %%
# 3. How would you remove duplicates in Excel.

# %%
# 4. When and Where do you we use conditional formatting in Excel.
