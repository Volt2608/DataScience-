# %%
# 1. What all are the Python laibraries that you have used in Data Analytics.

# %%
# 2. Explain the tasks and functions you used the most in Pandas for Data Alalytics.

# %%
# 3. Explain the tasks and functions you used the most in Numpy for Data Alalytics.

# %%
# 4. What is the difference between Pandas and Numpy.

# %%
# 5. If you make Graphs, what Liab do you use and why?

# %%
# 6. Can you vizualise your data using Pandas or we can only use Matplotlib or Seaborn?
# if yes, how in Pandas and why.

# %%
# 7. How do you handle Missing Data in Python.

# %%
# 8. What is the difference between Python and R.
