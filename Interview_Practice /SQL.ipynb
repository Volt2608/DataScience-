# %%
# 1. What is the difference between WHERE and HAVING claus. And what are their uses.

# %%
# 2. Explain JOINS, How to apply a type of join on a table.

# %%
# 3. Querry writing - Ex. Write a querry to find highest and the second highest sale in city.

# %%
# 4. Pivot table.

# %%
# 5. What is the difference between DELETE, DROPE, TRUNCATE.
