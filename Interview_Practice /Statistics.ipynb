# %%
# 1. What are Mean, Mean, Medean Mode. In Data Analytics when do we use them.

# %%
# 2. What is Standard Daviation, And why it is used in Data Alalytics.

# %%
# 3. What is the difference between correlation and causation?
