# %%
# Training ML Algorithm on Iris Dataset -

# %%
# Before even you start Seperate Iris data into two parts, one for training and another for testing.
# 1. Import Libraries - 
# 2. Load Your CSV File
# 3. Separate Features and Label - since we have to use them as args in our model.fit()
# 4. Train the Model
# 5. Inference

# We have iris DataSet - 
# Why use RandomForestClassifier?

# Because:
# The goal is classification (predicting a flower species → a category).
# The data is labeled (we know the true species for training samples).
# RandomForestClassifier is supervised and built for classification.
# So it fits perfectly for the Iris dataset.
#------------------------------------------------------
# model.fit() -  The Training Function
# In scikit-learn, every machine learning model (like RandomForestClassifier, DecisionTreeClassifier, LinearRegression, etc.)
# has a .fit() method used to train the model.

# Syntax
# model.fit(X, y)
# X → your features (independent variables, input data)
# y → your labels (target variable, what you want to predict)

# %%
#------------code----------below------------Self---------Practice---------------

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

data = pd.read_csv("3.irisTest.csv")
data.head(10)

# %%
x = data.iloc[ :, :-1]
y = data.iloc[:, -1]

# %%
model = RandomForestClassifier()
model.fit(x.values, y.values)
# Out:
# RandomForestClassifier()

# %%
prediction = model.predict([[5.2,	3.4,	1.4,	0.2]])

# %%
predictions

# %%
dataTrain = pd.read_csv("3.irisTrain.csv")
x_test = data.iloc[ :, :-1]
y_test = data.iloc[:, -1]

# %%
predictionsTest = model.predict(x_test.values)

# %%
predictionsTest

# %%
actual = y_test.values 
actual
# Out:
# array(['Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa'], dtype=object)

# %%
count = 0 
for i in range(0, len(actual)):   
    if actual[i] == predictionsTest[i]:
     count = count + 1    
accuracy = print(count*100/len(actual))    # percentage
# Out:
# 100.0

# %%
# Measuring Accuracy of our Predictions - 
# When we build a machine learning model, especially a classification model (which predicts categories like "spam" or "not spam", "dog" or "cat"), it's important to measure how well the model is performing.

# One of the most basic ways to evaluate a classification model is accuracy.

# What is Accuracy?
# In simple terms, accuracy tells us how often the model was right.

# %%
# If you gave your model 100 questions to answer, and it got 90 of them correct, its accuracy would be:

# Accuracy = Correct Predictions / Total Predictions = 90 / 100 = 90%
# So, accuracy is just the fraction of predictions the model got right.
# Out:
#   Cell In[94], line 1
#     If you gave your model 100 questions to answer, and it got 90 of them correct, its accuracy would be:
#        ^
# SyntaxError: invalid syntax

# %%
# Evaluating Accuracy - 
# Accuracy = (Correct Predictions) / (Total Predictions)

# This is the simplest and most intuitive way to check if the model is doing a good job.
